# %%
import pandas as pd 

dataframe = pd.read_csv("storingen.csv")

dataframe.groupby(["cause_nl"]).agg('count').sort_values("rdt_id", ascending=False)
# dataframe
# Out:
#                                           rdt_id  ns_lines  rdt_lines  \
# cause_nl
# defecte trein                               3144      3144       2971
# seinstoring                                 1865      1865       1824
# wisselstoring                               1756      1756       1673
# aanrijding met een persoon                  1637      1637       1616
# herstelwerkzaamheden                         801       801        518
# eerdere verstoring                           659       659        618
# sein-en overwegstoring                       491       491        489
# inzet van hulpdiensten                       437       437        423
# overwegstoring                               432       432        423
# sein-en wisselstoring                        426       426        417
# stroomstoring                                423       423        419
# defecte bovenleiding                         368       368        351
# ...
